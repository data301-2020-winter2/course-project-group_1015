# %% [markdown]
#  ### Research questions

# %%
import pandas as pd
import numpy as np
import os
from Combinedscripts import projectfunctions # This is called a relative import
df = projectfunctions.load_and_process('Data/raw/Medical_Cost.csv')

# %% [markdown]
# **Ques1) Which gender smokes the most?**

# %%
sns.histplot(data = df,x = 'Gender', hue = 'Tobacco User' , multiple = 'stack' )
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %% [markdown]
# We sorted tobacco users by gender with a histogram that showed a greater count of male tobacco users than female tobacco users.

# %% [markdown]
# **Ques2) Is there a relation between Medical costs and Age?**

# %%
sns.jointplot(x = 'Age', y = "Medical Costs per region",kind = 'hex',color = '#FF2D00', data = df1)

# %% [markdown]
# From the analysis, we concluded that Medical costs are generally higher for people of age above 45 but no actual pattern is seen (As seen in graph above).
# But due to older people being more addicted to smoking ,younger people have less medical costs as compared to older people.

# %% [markdown]
# **Ques3) Does having more children means expensive medical care?**

# %%
sns.relplot(x = 'Medical Costs per region', y = 'Age',hue = 'Gender',data = df1,size = 'Children',sizes = (10,200))

# %% [markdown]
# It is seen that having more children doesnt imply more costs as all the people with more than four children have costs under 10000 regardless of their age.From the graphs we can see that people with 0 children can have costs more than $60000.

# %% [markdown]
# **Ques4) Does any particular area has a higher medical costs?**

# %%
sns.stripplot(data = df1,y ='Medical Costs per region', x = 'Region',hue = 'Children', palette = 'colorblind' , alpha = 0.5 )
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Medical Costs per region'>

# %% [markdown]
# From the graph, we can see that the Southeast has the larger grouping after $35,000 meaning it has higher ranges of costs.

# %% [markdown]
# **Ques5) For what BMI has the most Medical Costs?**

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df1 = df.copy()
df1['Medical Costs per region'] = df1['Medical Costs per region'].str.replace('$','')
df1['Medical Costs per region'] = df1['Medical Costs per region'].astype(float)
sns.jointplot(data = df1 , x = 'BMI', y = 'Medical Costs per region',hue = 'Tobacco User',alpha = 0.5)
# Out:
# <ipython-input-3-5ce1dda500c6>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df1['Medical Costs per region'] = df1['Medical Costs per region'].str.replace('$','')

# %% [markdown]
# The most expensive medical charges are between BMI 30-40 as seen in the graph, but the highest medical cost charged was for the person with a BMI of approx 48. This concludes that in USA obese people end up paying more for their medical costs irrespective of other factors included.
#     From the analysis we also concluded that people with BMI between 30-40 are tobacco users which might play a factor in increased medical charges.

# %% [markdown]
# **Ques6) What are the different ranges of BMI?**

# %%
sns.displot(df['BMI'])

# %% [markdown]
# **Ques7) Does higher BMI results in more Medical Costs?**

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df1 = df.copy()
df1['Medical Costs per region'] = df1['Medical Costs per region'].str.replace('$','')
df1['Medical Costs per region'] = df1['Medical Costs per region'].astype(float)
f,ax = plt.subplots(figsize=(6,6))
sns.scatterplot(x = 'BMI', y = "Medical Costs per region", data = df1,s = 5,color = '.15')
sns.histplot(x = 'BMI', y = "Medical Costs per region", data = df1,bins = 150,pthresh = .1,cmap = 'mako')
sns.kdeplot(x = 'BMI', y = "Medical Costs per region", data = df1,levels = 10,color = 'b',linewidths= 1)
# Out:
# <ipython-input-5-34dbc027351c>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df1['Medical Costs per region'] = df1['Medical Costs per region'].str.replace('$','')
# <AxesSubplot:xlabel='BMI', ylabel='Medical Costs per region'>

# %% [markdown]
# This graph indicates that the higher the BMI rate the greater chance for the individual to contract diseases such as lung cancer from smoking.
